# %%
number = 0
with open('input_day01', 'r') as f:
    # Comment: input_day01
    for line in f:
        line_numbers = []
        for ch in line:
            if ch.isdigit():
                line_numbers.append(ch)
        number+=int(line_numbers[0]+line_numbers[-1])
        # print(f"line: {line} ... {line_numbers} ... {int(line_numbers[0]+line_numbers[-1])}")
    # end for
# end readline file
print(f"Day 1 result: {number}")
# Out:
# Day 1 result: 53974

# %%
 ## Day 1 Part 2

number_names = ['one','two','three','four','five','six','seven','eight','nine']
number_valeus = ['one1one','two2two','three3three','four4four','five5five','six6six','seven7seven','eight8eight','nine9nine']
number = 0


with open('input_day01', 'r') as f:
    # Comment: input_day01
    for line in f:
        print(f"{line}")
        for i in zip(number_names,number_valeus):
            line=line.replace(i[0],i[1])
        line_numbers = []
        for ch in line:
            if ch.isdigit():
                line_numbers.append(ch)
        number+=int(line_numbers[0]+line_numbers[-1])
        print(f"line: {line} ... {line_numbers} ... {int(line_numbers[0]+line_numbers[-1])}")
    # end for
# end readline file
print(f"Day 1 Part 2 result: {number}")
# Out:
# tmmnhlxzpj1eightldxhjnone97
#
# line: tmmnhlxzpj1eight8eightldxhjnone1one97
#  ... ['1', '8', '1', '9', '7'] ... 17
# 9fivekfpl855mjmfdqzvbn
#
# line: 9five5fivekfpl855mjmfdqzvbn
#  ... ['9', '5', '8', '5', '5'] ... 95
# two29eighteight1
#
# line: two2two29eight8eighteight8eight1
#  ... ['2', '2', '9', '8', '8', '1'] ... 21
# 4md
#
# line: 4md
#  ... ['4'] ... 44
# sixbrqklb347
#
# line: six6sixbrqklb347
#  ... ['6', '3', '4', '7'] ... 67
# 6sevenninexpnbgbr11three15
#
# line: 6seven7sevennine9ninexpnbgbr11three3three15
#  ... ['6', '7', '9', '1', '1', '3', '1', '5'] ... 65
# 4zggkljkcqthree7
#
# line: 4zggkljkcqthree3three7
#  ... ['4', '3', '7'] ... 47
# 7lxjkqhmxcxsevennhszsbxzdfsonehnsrcfour9
#
# line: 7lxjkqhmxcxseven7sevennhszsbxzdfsone1onehnsrcfour4four9
#  ... ['7', '7', '1', '4', '9'] ... 79
# jtpmfoureightvtjmlshbfour6nvjkqnddp3
#
# line: jtpmfour4foureight8eightvtjmlshbfour4four6nvjkqnddp3
#  ... ['4', '8', '4', '6', '3'] ... 43
# twofive2fourfive1dvnrrvjr
#
# ...

# %%
# bag contains:  12 red cubes, 13 green cubes, and 14 blue cubes
# which games would be possible

games = []
# with open('input_02.txt', 'r') as f:

# In the example above, games 1, 2, and 5 would have been possible if the bag had been loaded with that configuration. However, game 3 would have been impossible because at one point the Elf showed you 20 red cubes at once; similarly, game 4 would also have been impossible because the Elf showed you 15 blue cubes at once. If you add up the IDs of the games that would have been possible, you get 8.
with open('input_02_test.txt', 'r') as f:
    for line in f:
        # parse string into games
        txt = line.lstrip("Game ")
        colon_index = txt.find(":")
        coma_index = txt.find(";")
        while find
# Out:
# 1: 7 blue, 9 red, 1 green; 8 green; 10 green, 5 blue, 3 red; 11 blue, 5 red, 1 green
# ,
# 2: 7 green, 3 blue; 20 blue, 4 green; 6 red, 13 blue, 2 green
# ,
# 3: 11 blue, 3 red, 1 green; 15 red, 9 blue, 3 green; 11 blue, 4 red, 4 green; 1 red, 2 green, 14 blue; 18 blue, 4 green, 10 red
# ,
# 4: 3 red, 7 blue; 3 blue, 2 red, 2 green; 2 green, 1 red, 1 blue; 3 green, 5 blue, 5 red; 7 blue, 1 green, 1 red; 2 green, 7 blue
# ,
# 5: 1 blue, 2 red, 1 green; 6 blue, 3 green, 2 red; 2 blue
# ,
# 6: 5 green, 5 red, 5 blue; 9 blue, 6 green, 8 red; 7 green, 3 red, 15 blue; 9 blue, 9 green; 10 red, 12 blue, 4 green; 9 blue, 1 red, 9 green
# ,
# 7: 8 blue, 9 green, 16 red; 9 green, 9 blue; 10 red, 5 blue, 8 green; 9 green, 17 red, 2 blue; 1 blue, 18 red, 8 green; 3 green, 8 blue, 14 red
# ,
# 8: 6 green, 8 blue, 16 red; 10 green, 1 blue, 4 red; 2 blue, 15 red, 10 green; 7 green, 9 red, 2 blue; 17 red, 4 green, 7 blue
# ,
# ...
